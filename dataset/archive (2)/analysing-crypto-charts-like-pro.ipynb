# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cardano-cryoto-price/ADA-USD.csv
# /kaggle/input/bitcoin-not-looking-good/BTC-USD.csv
# /kaggle/input/ethereum-pricing-20202022/ETH.csv
# /kaggle/input/doge-coin/DOGE-USD.csv
# /kaggle/input/solana-cryptocurrency-historical-dataset/Solana Historical Data.csv
# /kaggle/input/binance-coin-usd-bnbusd/BNB-USD.csv

# %% [markdown]
# <div style = 'position: relative; text-align: center; color: white;'>
#   <img src="https://png.pngtree.com/thumb_back/fh260/background/20190421/pngtree-blockchain-technology-background-image_107831.jpg" style="width:100%;border-radius: 25px;">
#   <div style = 'position: absolute; top: 50%; left: 50%;transform: translate(-50%, -50%);font-size: 25px;font-weight: bold;'>
# 📈 Crypto Technical Analysis (Price Action)</div>
# </div>

# %% [markdown]
# <img src= "https://pa1.narvii.com/7322/0151fad04faac0c08e9545a99d4eb4180bd0c06fr1-640-275_hq.gif" alt ="Crypto" >

# %%
import plotly.graph_objects as go

import pandas as pd
from datetime import datetime

# %%
btc = pd.read_csv('/kaggle/input/bitcoin-not-looking-good/BTC-USD.csv')
btc['Date'] = pd.to_datetime(btc['Date'], infer_datetime_format=False)
btc.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
eth = pd.read_csv('/kaggle/input/ethereum-pricing-20202022/ETH.csv')
eth['Date'] = pd.to_datetime(eth['Date'], infer_datetime_format=False)
eth.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-06-16  229.762299  236.394302  228.426147  234.416168  234.416168
# 1 2020-06-17  234.492371  235.954056  229.341644  233.028275  233.028275
# 2 2020-06-18  232.898697  234.570648  228.951431  232.101166  232.101166
# 3 2020-06-19  231.954971  232.154114  226.795181  227.138290  227.138290
# 4 2020-06-20  226.976364  231.449020  226.640625  229.274261  229.274261
#
#        Volume
# 0  7965648016
# 1  7701391592
# 2  6713800872
# 3  6946372590
# 4  6252830566

# %%
doge = pd.read_csv('/kaggle/input/doge-coin/DOGE-USD.csv')
doge['Date'] = pd.to_datetime(doge['Date'], infer_datetime_format=False)
doge.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2017-11-09  0.001207  0.001415  0.001181  0.001415   0.001415  6259550.0
# 1 2017-11-10  0.001421  0.001431  0.001125  0.001163   0.001163  4246520.0
# 2 2017-11-11  0.001146  0.001257  0.001141  0.001201   0.001201  2231080.0
# 3 2017-11-12  0.001189  0.001210  0.001002  0.001038   0.001038  3288960.0
# 4 2017-11-13  0.001046  0.001212  0.001019  0.001211   0.001211  2481270.0

# %%
ada = pd.read_csv('/kaggle/input/cardano-cryoto-price/ADA-USD.csv')
ada['Date'] = pd.to_datetime(ada['Date'], infer_datetime_format=False)
ada.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close    Volume
# 0 2017-11-09  0.025160  0.035060  0.025006  0.032053   0.032053  18716200
# 1 2017-11-10  0.032219  0.033348  0.026451  0.027119   0.027119   6766780
# 2 2017-11-11  0.026891  0.029659  0.025684  0.027437   0.027437   5532220
# 3 2017-11-12  0.027480  0.027952  0.022591  0.023977   0.023977   7280250
# 4 2017-11-13  0.024364  0.026300  0.023495  0.025808   0.025808   4419440

# %%
sol = pd.read_csv('/kaggle/input/solana-cryptocurrency-historical-dataset/Solana Historical Data.csv')
sol['Date'] = pd.to_datetime(sol['Date'], infer_datetime_format=False)
sol.head()
# Out:
#         Date      Open      High       Low     Close    Volume
# 0 2020-04-10  0.832005  1.313487  0.694187  0.951054  87364276
# 1 2020-04-11  0.951054  1.049073  0.765020  0.776819  43862444
# 2 2020-04-12  0.785448  0.956670  0.762426  0.882507  38736897
# 3 2020-04-13  0.890760  0.891603  0.773976  0.777832  18211285
# 4 2020-04-14  0.777832  0.796472  0.628169  0.661925  16747614

# %%
bnb = pd.read_csv('/kaggle/input/binance-coin-usd-bnbusd/BNB-USD.csv')
bnb['Date'] = pd.to_datetime(bnb['Date'], infer_datetime_format=False)
bnb.head()
# Out:
#         Date     Open     High      Low    Close  Adj Close    Volume
# 0 2017-11-09  2.05314  2.17423  1.89394  1.99077    1.99077  19192200
# 1 2017-11-10  2.00773  2.06947  1.64478  1.79684    1.79684  11155000
# 2 2017-11-11  1.78628  1.91775  1.61429  1.67047    1.67047   8178150
# 3 2017-11-12  1.66889  1.67280  1.46256  1.51969    1.51969  15298700
# 4 2017-11-13  1.52601  1.73502  1.51760  1.68662    1.68662  12238800

# %% [markdown]
# <div style = 'position: relative; text-align: center; color: white;'>
#   <img src="https://png.pngtree.com/thumb_back/fh260/background/20190421/pngtree-blockchain-technology-background-image_107831.jpg" style="width:100%;border-radius: 25px;">
#   <div style = 'position: absolute; top: 50%; left: 50%;transform: translate(-50%, -50%);font-size: 25px;font-weight: bold;'>
# ₿itcoin Technical Analysis</div>
# </div>

# %% [markdown]
# <img src= "https://c.tenor.com/y0SIaspW0E8AAAAC/cyberhornet-nest.gif" alt ="Bitcoin" >

# %% [markdown]
# # ₿ITCOIN

# %%
fig = go.Figure()

fig.add_trace(
    go.Scatter(x=list(btc.Date), y=list(btc.High)))

# Set title
fig.update_layout(
    title_text="BTC Time series with range slider and selectors"
)
fig.add_layout_image(
    dict(
        source="https://image.shutterstock.com/image-vector/bitcoin-logo-currency-crypto-here-260nw-767986060.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=btc['Date'],
                open=btc['Open'],
                high=btc['High'],
                low=btc['Low'],
                close=btc['Close'])])

fig.add_layout_image(
    dict(
        source="https://image.shutterstock.com/image-vector/bitcoin-logo-currency-crypto-here-260nw-767986060.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)

fig.update_layout(
    title='BTC Price Over Time',
    yaxis_title='BTC Price',
    shapes = [dict(
        x0='2021-11-01', x1='2022-07-20', y0=0, y1=1, xref='x', yref='paper',
        line_width=2)],
    annotations=[dict(
        x='2021-11-01', y=0.05, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Bear Market Begins')]
)

fig.show()
# Out:
# <div>                            <div id="3f290681-1a79-43df-a427-112a71e44ce8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f290681-1a79-43df-a427-112a71e44ce8")) {                    Plotly.newPlot(                        "3f290681-1a79-43df-a427-112a71e44ce8",                        [{"close":[457.334015,424.440002,394.79599,408.903992,398.821014,402.152008,435.790985,423.204987,411.574005,404.424988,399.519989,377.181,375.46701,386.944,383.61499,375.071991,359.511993,328.865997,320.51001,330.07901,336.187012,352.940002,365.026001,361.562012,362.299011,378.549011,390.414001,400.869995,394.77301,382.556,383.757996,391.441986,389.54599,382.845001,386.475006,383.15799,358.416992,358.345001,347.270996,354.70401,352.989014,357.618011,335.591003,34
# ...

# %%
btc_recent = btc[btc['Date'] > '2021-12-30']

fig = go.Figure(data=[go.Candlestick(x=btc_recent['Date'],
                open=btc_recent['Open'],
                high=btc_recent['High'],
                low=btc_recent['Low'],
                close=btc_recent['Close'])])
fig.add_layout_image(
    dict(
        source="https://image.shutterstock.com/image-vector/bitcoin-logo-currency-crypto-here-260nw-767986060.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
fig.update_layout(
    title='BTC Price In 2022',
    yaxis_title='BTC Price',
)
fig.show()
# Out:
# <div>                            <div id="487d5b40-7a9c-48e8-adbf-d4d0b82a3384" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("487d5b40-7a9c-48e8-adbf-d4d0b82a3384")) {                    Plotly.newPlot(                        "487d5b40-7a9c-48e8-adbf-d4d0b82a3384",                        [{"close":[46306.445313,47686.8125,47345.21875,46458.117188,45897.574219,43569.003906,43160.929688,41557.902344,41733.941406,41911.601563,41821.261719,42735.855469,43949.101563,42591.570313,43099.699219,43177.398438,43113.878906,42250.550781,42375.632813,41744.328125,40680.417969,36457.316406,35030.25,36276.804688,36654.328125,36954.003906,36852.121094,37138.234375,37784.332031,38138.179688,37917.601563,38483.125,38743.273438,36952.984375,37154.601563,41500.875,41
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=btc['Date'],
                open=btc['Open'],
                high=btc['High'],
                low=btc['Low'],
                close=btc['Close'])])
fig.add_layout_image(
    dict(
        source="https://image.shutterstock.com/image-vector/bitcoin-logo-currency-crypto-here-260nw-767986060.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)

fig.add_trace(go.Scatter(x=['2017-12-02','2022-06-26'], y=[20000,20000], mode='lines', name='trend line', line=dict(color='blue')))
fig.add_trace(go.Scatter(x=['2018-01-02','2022-06-26'], y=[18000,18000], mode='lines', name='trend line', line=dict(color='green')))
fig.add_trace(go.Scatter(x=['2019-06-02','2022-06-26'], y=[14000,14000], mode='lines', name='trend line', line=dict(color='purple')))
fig.update_layout(
    title='BTC Important Support Levels',
    yaxis_title='BTC Price',
    xaxis_rangeslider_visible=False,
    annotations=[dict(
        x='2022-04-20', y=0.1, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Important Support Levels')]
)
# Out:
# <div>                            <div id="3973519b-6044-4cd8-a00b-de5be9d3fe9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3973519b-6044-4cd8-a00b-de5be9d3fe9d")) {                    Plotly.newPlot(                        "3973519b-6044-4cd8-a00b-de5be9d3fe9d",                        [{"close":[457.334015,424.440002,394.79599,408.903992,398.821014,402.152008,435.790985,423.204987,411.574005,404.424988,399.519989,377.181,375.46701,386.944,383.61499,375.071991,359.511993,328.865997,320.51001,330.07901,336.187012,352.940002,365.026001,361.562012,362.299011,378.549011,390.414001,400.869995,394.77301,382.556,383.757996,391.441986,389.54599,382.845001,386.475006,383.15799,358.416992,358.345001,347.270996,354.70401,352.989014,357.618011,335.591003,34
# ...

# %% [markdown]
# <div style = 'position: relative; text-align: center; color: white;'>
#   <img src="https://png.pngtree.com/thumb_back/fh260/background/20190421/pngtree-blockchain-technology-background-image_107831.jpg" style="width:100%;border-radius: 25px;">
#   <div style = 'position: absolute; top: 50%; left: 50%;transform: translate(-50%, -50%);font-size: 25px;font-weight: bold;'>
# Ethereum Technical Analysis</div>
# </div>

# %% [markdown]
# <img src= "https://media3.giphy.com/media/MagSgolK3ScWvtHAB4/giphy.gif" alt ="ETH" >

# %% [markdown]
# # ETH

# %%
fig = go.Figure()

fig.add_trace(
    go.Scatter(x=list(eth.Date), y=list(eth.High)))

# Set title
fig.update_layout(
    title_text="ETH Coin Time series with range slider and selectors"
)
fig.add_layout_image(
    dict(
        source="https://play-lh.googleusercontent.com/HII6PADUEGHBXs_EhvB67Nfdn5nxMpyx51mZxAghukYNqEB5LysYPB1afCctDAud1ho",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
# <div>                            <div id="889d3ab5-868a-4cc0-8e5e-7d211c624d5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("889d3ab5-868a-4cc0-8e5e-7d211c624d5c")) {                    Plotly.newPlot(                        "889d3ab5-868a-4cc0-8e5e-7d211c624d5c",                        [{"x":["2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-04T00:00:00","2020-07-05T00:00:00","2020-07-06T00:00:00"
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=eth['Date'],
                open=eth['Open'],
                high=eth['High'],
                low=eth['Low'],
                close=eth['Close'])])

fig.add_layout_image(
    dict(
        source="https://play-lh.googleusercontent.com/HII6PADUEGHBXs_EhvB67Nfdn5nxMpyx51mZxAghukYNqEB5LysYPB1afCctDAud1ho",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)

fig.update_layout(
    title='ETH Price Over Time',
    yaxis_title='ETH Price',
    shapes = [dict(
        x0='2021-12-01', x1='2022-07-01', y0=0, y1=1, xref='x', yref='paper',
        line_width=2)],
    annotations=[dict(
        x='2022-05-09', y=0.05, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Bear Market Begins')]
)

fig.show()
# Out:
# <div>                            <div id="51926f84-cf75-4fd2-b35e-a37ac844542d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51926f84-cf75-4fd2-b35e-a37ac844542d")) {                    Plotly.newPlot(                        "51926f84-cf75-4fd2-b35e-a37ac844542d",                        [{"close":[234.416168,233.028275,232.101166,227.13829,229.274261,228.989822,242.533188,244.142151,235.772461,232.944489,229.668045,222.959793,225.347168,228.19487,226.315002,231.113419,229.392197,225.38707,229.074112,227.664597,241.510223,239.075531,246.670013,243.015961,240.984985,239.458176,242.131699,239.604584,240.211487,238.423523,233.640884,232.773087,235.48381,238.487518,236.153168,245.016724,262.190643,274.689056,279.215424,304.056763,309.643616,321.514099
# ...

# %%
eth_recent = eth[eth['Date'] > '2021-12-30']

fig = go.Figure(data=[go.Candlestick(x=eth_recent['Date'],
                open=eth_recent['Open'],
                high=eth_recent['High'],
                low=eth_recent['Low'],
                close=eth_recent['Close'])])
fig.add_layout_image(
    dict(
        source="https://play-lh.googleusercontent.com/HII6PADUEGHBXs_EhvB67Nfdn5nxMpyx51mZxAghukYNqEB5LysYPB1afCctDAud1ho",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
fig.update_layout(
    title='ETH Price In 2022',
    yaxis_title='ETH Price',
)
fig.show()
# Out:
# <div>                            <div id="123203db-1915-4ce5-ab13-a19487449dc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("123203db-1915-4ce5-ab13-a19487449dc7")) {                    Plotly.newPlot(                        "123203db-1915-4ce5-ab13-a19487449dc7",                        [{"close":[3682.632813,3769.697021,3829.564941,3761.380371,3794.056641,3550.386963,3418.408203,3193.210449,3091.972656,3157.751465,3083.0979,3238.111572,3372.258301,3248.288574,3310.001465,3330.530762,3350.921875,3212.304932,3164.025146,3095.825928,3001.120117,2557.931641,2405.181152,2535.039063,2440.352295,2455.935059,2468.030273,2423.001221,2547.092041,2597.084717,2603.466553,2688.278809,2792.117188,2682.854004,2679.162598,2983.586914,3014.648193,3057.476074,314
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=eth['Date'],
                open=eth['Open'],
                high=eth['High'],
                low=eth['Low'],
                close=eth['Close'])])
fig.add_layout_image(
    dict(
        source="https://play-lh.googleusercontent.com/HII6PADUEGHBXs_EhvB67Nfdn5nxMpyx51mZxAghukYNqEB5LysYPB1afCctDAud1ho",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)

fig.add_trace(go.Scatter(x=['2021-05-02','2022-06-26'], y=[1700,1700], mode='lines', name='trend line', line=dict(color='blue')))
fig.add_trace(go.Scatter(x=['2021-01-12','2022-06-26'], y=[910,910], mode='lines', name='trend line', line=dict(color='green')))
fig.add_trace(go.Scatter(x=['2020-12-02','2022-06-26'], y=[650,650], mode='lines', name='trend line', line=dict(color='purple')))
fig.update_layout(
    title='ETH Important Support Levels',
    yaxis_title='ETH Price',
    xaxis_rangeslider_visible=False,
    annotations=[dict(
        x='2022-04-20', y=0.07, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Important Support Levels')]
)
# Out:
# <div>                            <div id="74a077bc-f88d-43b9-acd9-2a060082cbc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74a077bc-f88d-43b9-acd9-2a060082cbc6")) {                    Plotly.newPlot(                        "74a077bc-f88d-43b9-acd9-2a060082cbc6",                        [{"close":[234.416168,233.028275,232.101166,227.13829,229.274261,228.989822,242.533188,244.142151,235.772461,232.944489,229.668045,222.959793,225.347168,228.19487,226.315002,231.113419,229.392197,225.38707,229.074112,227.664597,241.510223,239.075531,246.670013,243.015961,240.984985,239.458176,242.131699,239.604584,240.211487,238.423523,233.640884,232.773087,235.48381,238.487518,236.153168,245.016724,262.190643,274.689056,279.215424,304.056763,309.643616,321.514099
# ...

# %% [markdown]
# <div style = 'position: relative; text-align: center; color: white;'>
#   <img src="https://png.pngtree.com/thumb_back/fh260/background/20190421/pngtree-blockchain-technology-background-image_107831.jpg" style="width:100%;border-radius: 25px;">
#   <div style = 'position: absolute; top: 50%; left: 50%;transform: translate(-50%, -50%);font-size: 25px;font-weight: bold;'>
# DogeCoin Technical Analysis</div>
# </div>

# %% [markdown]
# <img src= "https://media0.giphy.com/media/9FQ89bO3TipLASwmRs/giphy.gif?cid=6c09b9524f066bedbedd9c700ead9541b96fb347d262e7a4&rid=giphy.gif&ct=g" alt ="doge" >

# %% [markdown]
# # Doge Coin

# %%
fig = go.Figure()

fig.add_trace(
    go.Scatter(x=list(doge.Date), y=list(doge.High)))

# Set title
fig.update_layout(
    title_text="DogeCoin Time series with range slider and selectors"
)
fig.add_layout_image(
    dict(
        source="https://upload.wikimedia.org/wikipedia/en/d/d0/Dogecoin_Logo.png",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
# <div>                            <div id="b38edca5-205b-4f23-8794-709027ff3718" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b38edca5-205b-4f23-8794-709027ff3718")) {                    Plotly.newPlot(                        "b38edca5-205b-4f23-8794-709027ff3718",                        [{"x":["2017-11-09T00:00:00","2017-11-10T00:00:00","2017-11-11T00:00:00","2017-11-12T00:00:00","2017-11-13T00:00:00","2017-11-14T00:00:00","2017-11-15T00:00:00","2017-11-16T00:00:00","2017-11-17T00:00:00","2017-11-18T00:00:00","2017-11-19T00:00:00","2017-11-20T00:00:00","2017-11-21T00:00:00","2017-11-22T00:00:00","2017-11-23T00:00:00","2017-11-24T00:00:00","2017-11-25T00:00:00","2017-11-26T00:00:00","2017-11-27T00:00:00","2017-11-28T00:00:00","2017-11-29T00:00:00"
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=doge['Date'],
                open=doge['Open'],
                high=doge['High'],
                low=doge['Low'],
                close=doge['Close'])])

fig.add_layout_image(
    dict(
        source="https://upload.wikimedia.org/wikipedia/en/d/d0/Dogecoin_Logo.png",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)

fig.update_layout(
    title='Doge Price Over Time',
    yaxis_title='Doge Price',
    shapes = [dict(
        x0='2021-06-01', x1='2022-06-20', y0=0, y1=1, xref='x', yref='paper',
        line_width=2)],
    annotations=[dict(
        x='2022-03-01', y=0.05, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Bear Market Begins')]
)

fig.show()
# Out:
# <div>                            <div id="dd62c365-e1fb-4190-a246-0fb2174effdc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd62c365-e1fb-4190-a246-0fb2174effdc")) {                    Plotly.newPlot(                        "dd62c365-e1fb-4190-a246-0fb2174effdc",                        [{"close":[0.001415,0.001163,0.001201,0.001038,0.001211,0.001184,0.001339,0.00139,0.001313,0.001373,0.001376,0.001394,0.001389,0.001823,0.001891,0.001908,0.002072,0.002026,0.001988,0.002363,0.00208,0.002079,0.002148,0.002149,0.002223,0.002463,0.002479,0.002663,0.00272,0.002779,0.002617,0.002547,0.002798,0.003304,0.003461,0.003709,0.003762,0.005933,0.005984,0.006433,0.005666,0.006661,0.007425,0.006054,0.007259,0.008582,0.008931,0.009411,0.008872,0.008486,0.009391,0
# ...

# %%
doge_recent = doge[doge['Date'] > '2021-12-30']

fig = go.Figure(data=[go.Candlestick(x=doge_recent['Date'],
                open=doge_recent['Open'],
                high=doge_recent['High'],
                low=doge_recent['Low'],
                close=doge_recent['Close'])])
fig.add_layout_image(
    dict(
        source="https://upload.wikimedia.org/wikipedia/en/d/d0/Dogecoin_Logo.png",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
fig.update_layout(
    title='Doge Price In 2022',
    yaxis_title='Doge Price',
)
fig.show()
# Out:
# <div>                            <div id="2a14aa41-9465-4794-bf27-d0405a34cd5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a14aa41-9465-4794-bf27-d0405a34cd5a")) {                    Plotly.newPlot(                        "2a14aa41-9465-4794-bf27-d0405a34cd5a",                        [{"close":[0.170496,0.173035,0.174403,0.170088,0.168803,0.15942,0.160213,0.155023,0.151954,0.151065,0.143359,0.153399,0.161652,0.172043,0.183549,0.185103,0.177176,0.171145,0.165485,0.162356,0.155204,0.14264,0.132892,0.141863,0.137798,0.143049,0.143789,0.141247,0.141656,0.143056,0.139471,0.141805,0.142631,0.137235,0.137541,0.147503,0.147141,0.15377,0.165578,0.158405,0.159123,0.151889,0.144847,0.144405,0.148948,0.146003,0.151761,0.149095,0.138552,0.138768,0.141206,0
# ...

# %%
doge_recent = doge[doge['Date'] > '2021-01-01']

fig = go.Figure(data=[go.Candlestick(x=doge_recent['Date'],
                open=doge_recent['Open'],
                high=doge_recent['High'],
                low=doge_recent['Low'],
                close=doge_recent['Close'])])
fig.add_layout_image(
    dict(
        source="https://upload.wikimedia.org/wikipedia/en/d/d0/Dogecoin_Logo.png",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
fig.add_trace(go.Scatter(x=['2021-02-03','2022-06-26'], y=[0.08,0.08], mode='lines', name='trend line', line=dict(color='blue')))
fig.add_trace(go.Scatter(x=['2021-03-12','2022-06-26'], y=[0.06,0.06], mode='lines', name='trend line', line=dict(color='green')))
fig.add_trace(go.Scatter(x=['2021-02-02','2022-06-26'], y=[0.04,0.04], mode='lines', name='trend line', line=dict(color='purple')))
fig.update_layout(
    title='Doge Important Support Levels',
    yaxis_title='Doge Price',
    xaxis_rangeslider_visible=False,
    annotations=[dict(
        x='2022-04-20', y=0.03, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Important Support Levels')]
)
# Out:
# <div>                            <div id="7df0c35f-1c55-467b-9b16-54aa91be7701" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7df0c35f-1c55-467b-9b16-54aa91be7701")) {                    Plotly.newPlot(                        "7df0c35f-1c55-467b-9b16-54aa91be7701",                        [{"close":[0.010615,0.009771,0.009767,0.00992,0.010465,0.009742,0.009846,0.010194,0.00986,0.008835,0.008063,0.008616,0.009397,0.009369,0.009265,0.009067,0.009171,0.009098,0.00906,0.008166,0.008524,0.008579,0.008727,0.008383,0.008255,0.007482,0.034084,0.047162,0.028176,0.037196,0.034875,0.03152,0.03712,0.053289,0.046935,0.057595,0.078782,0.078825,0.07007,0.072896,0.069676,0.070069,0.06645,0.062537,0.056591,0.05352,0.049376,0.059541,0.055139,0.054384,0.05598,0.05372
# ...

# %% [markdown]
# <div style = 'position: relative; text-align: center; color: white;'>
#   <img src="https://png.pngtree.com/thumb_back/fh260/background/20190421/pngtree-blockchain-technology-background-image_107831.jpg" style="width:100%;border-radius: 25px;">
#   <div style = 'position: absolute; top: 50%; left: 50%;transform: translate(-50%, -50%);font-size: 25px;font-weight: bold;'>
# Cardano Technical Analysis</div>
# </div>

# %% [markdown]
# <img src= "https://c.tenor.com/TP5AXmfyi88AAAAC/cardano-ada.gif" alt ="doge" >

# %% [markdown]
# # Cardano

# %%
fig = go.Figure()

fig.add_trace(
    go.Scatter(x=list(ada.Date), y=list(ada.High)))

# Set title
fig.update_layout(
    title_text="Cardano Time series with range slider and selectors"
)
fig.add_layout_image(
    dict(
        source="https://upload.wikimedia.org/wikipedia/commons/c/c0/Cardano_Logo.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
# <div>                            <div id="02fe58b9-cf52-4b04-8f4e-bc2a38215f2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02fe58b9-cf52-4b04-8f4e-bc2a38215f2b")) {                    Plotly.newPlot(                        "02fe58b9-cf52-4b04-8f4e-bc2a38215f2b",                        [{"x":["2017-11-09T00:00:00","2017-11-10T00:00:00","2017-11-11T00:00:00","2017-11-12T00:00:00","2017-11-13T00:00:00","2017-11-14T00:00:00","2017-11-15T00:00:00","2017-11-16T00:00:00","2017-11-17T00:00:00","2017-11-18T00:00:00","2017-11-19T00:00:00","2017-11-20T00:00:00","2017-11-21T00:00:00","2017-11-22T00:00:00","2017-11-23T00:00:00","2017-11-24T00:00:00","2017-11-25T00:00:00","2017-11-26T00:00:00","2017-11-27T00:00:00","2017-11-28T00:00:00","2017-11-29T00:00:00"
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=ada['Date'],
                open=ada['Open'],
                high=ada['High'],
                low=ada['Low'],
                close=ada['Close'])])

fig.add_layout_image(
    dict(
        source="https://upload.wikimedia.org/wikipedia/commons/c/c0/Cardano_Logo.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)

fig.update_layout(
    title='Cardano Price Over Time',
    yaxis_title='Cardano Price',
    shapes = [dict(
        x0='2021-09-01', x1='2022-07-20', y0=0, y1=1, xref='x', yref='paper',
        line_width=2)],
    annotations=[dict(
        x='2022-06-01', y=0.05, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Bear Market Begins')]
)

fig.show()
# Out:
# <div>                            <div id="89416aa0-8459-41c8-b7e8-cdaaa4ffa8a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89416aa0-8459-41c8-b7e8-cdaaa4ffa8a1")) {                    Plotly.newPlot(                        "89416aa0-8459-41c8-b7e8-cdaaa4ffa8a1",                        [{"close":[0.032053,0.027119,0.027437,0.023977,0.025808,0.02623,0.026445,0.02758,0.025773,0.026369,0.028084,0.029581,0.02833,0.028549,0.027444,0.028382,0.030447,0.036332,0.050593,0.119744,0.089718,0.119883,0.131352,0.132351,0.131807,0.13587,0.127488,0.117839,0.105501,0.115465,0.119609,0.110281,0.121383,0.133891,0.134281,0.240753,0.213467,0.404665,0.513011,0.518198,0.531273,0.486151,0.477851,0.40715,0.414027,0.390029,0.416363,0.428465,0.414176,0.407701,0.529299,0.6
# ...

# %%
ada_recent = ada[ada['Date'] > '2021-12-30']

fig = go.Figure(data=[go.Candlestick(x=ada_recent['Date'],
                open=ada_recent['Open'],
                high=ada_recent['High'],
                low=ada_recent['Low'],
                close=ada_recent['Close'])])
fig.add_layout_image(
    dict(
        source="https://upload.wikimedia.org/wikipedia/commons/c/c0/Cardano_Logo.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
fig.update_layout(
    title='Cardano Price In 2022',
    yaxis_title='Cardano Price',
)
fig.show()
# Out:
# <div>                            <div id="174814b3-19f0-4f2e-a19e-6b5c141252d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("174814b3-19f0-4f2e-a19e-6b5c141252d6")) {                    Plotly.newPlot(                        "174814b3-19f0-4f2e-a19e-6b5c141252d6",                        [{"close":[1.310209,1.376975,1.377584,1.321637,1.311658,1.236002,1.279782,1.211547,1.187512,1.17386,1.128052,1.18511,1.304535,1.233161,1.290926,1.296263,1.407251,1.594131,1.465541,1.341757,1.258055,1.123233,1.066716,1.122371,1.066598,1.043574,1.079047,1.043533,1.050606,1.05957,1.037473,1.052303,1.088624,1.028906,1.056444,1.135624,1.127345,1.144547,1.197307,1.17872,1.19481,1.152478,1.080347,1.058199,1.045819,1.050267,1.107586,1.084981,1.019895,0.997113,0.997703,0.9
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=ada['Date'],
                open=ada['Open'],
                high=ada['High'],
                low=ada['Low'],
                close=ada['Close'])])

fig.add_trace(go.Scatter(x=['2018-02-25','2022-06-03'], y=[0.40,0.40], mode='lines', name='trend line', line=dict(color='blue')))
fig.add_trace(go.Scatter(x=['2017-12-13','2022-06-03'], y=[0.3,0.3], mode='lines', name='trend line', line=dict(color='purple')))
fig.add_layout_image(
    dict(
        source="https://upload.wikimedia.org/wikipedia/commons/c/c0/Cardano_Logo.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
fig.update_layout(
    title='Cardano Important Support Levels',
    yaxis_title='Cardano Price',
    xaxis_rangeslider_visible=False,
    annotations=[dict(
        x='2022-04-20', y=0.07, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Important Support Levels')]
)
# Out:
# <div>                            <div id="07d99bdc-257b-470e-ada8-fa9b7d3dddbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07d99bdc-257b-470e-ada8-fa9b7d3dddbb")) {                    Plotly.newPlot(                        "07d99bdc-257b-470e-ada8-fa9b7d3dddbb",                        [{"close":[0.032053,0.027119,0.027437,0.023977,0.025808,0.02623,0.026445,0.02758,0.025773,0.026369,0.028084,0.029581,0.02833,0.028549,0.027444,0.028382,0.030447,0.036332,0.050593,0.119744,0.089718,0.119883,0.131352,0.132351,0.131807,0.13587,0.127488,0.117839,0.105501,0.115465,0.119609,0.110281,0.121383,0.133891,0.134281,0.240753,0.213467,0.404665,0.513011,0.518198,0.531273,0.486151,0.477851,0.40715,0.414027,0.390029,0.416363,0.428465,0.414176,0.407701,0.529299,0.6
# ...

# %% [markdown]
# <div style = 'position: relative; text-align: center; color: white;'>
#   <img src="https://png.pngtree.com/thumb_back/fh260/background/20190421/pngtree-blockchain-technology-background-image_107831.jpg" style="width:100%;border-radius: 25px;">
#   <div style = 'position: absolute; top: 50%; left: 50%;transform: translate(-50%, -50%);font-size: 25px;font-weight: bold;'>
# Solana Technical Analysis</div>
# </div>

# %% [markdown]
# <img src= "https://miro.medium.com/max/1040/1*Sb_5AKHzj6KLkSQh4diWuA.gif" alt ="sol" >

# %% [markdown]
# # SOLANA

# %%
fig = go.Figure()

fig.add_trace(
    go.Scatter(x=list(sol.Date), y=list(sol.High)))

# Set title
fig.update_layout(
    title_text="Solana Time series with range slider and selectors"
)
fig.add_layout_image(
    dict(
        source="https://pbs.twimg.com/profile_images/1472933274209107976/6u-LQfjG_400x400.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
# <div>                            <div id="6e98c317-ea39-40dc-8b2b-716461deeace" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e98c317-ea39-40dc-8b2b-716461deeace")) {                    Plotly.newPlot(                        "6e98c317-ea39-40dc-8b2b-716461deeace",                        [{"x":["2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00"
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=sol['Date'],
                open=sol['Open'],
                high=sol['High'],
                low=sol['Low'],
                close=sol['Close'])])

fig.add_layout_image(
    dict(
        source="https://pbs.twimg.com/profile_images/1472933274209107976/6u-LQfjG_400x400.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)

fig.update_layout(
    title='Solana Price Over Time',
    yaxis_title='Solana Price',
    shapes = [dict(
        x0='2021-11-10', x1='2022-07-20', y0=0, y1=1, xref='x', yref='paper',
        line_width=2)],
    annotations=[dict(
        x='2022-06-01', y=0.05, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Bear Market Begins')]
)

fig.show()
# Out:
# <div>                            <div id="b6ee9ca4-5472-4e85-9b22-cf896646d1a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6ee9ca4-5472-4e85-9b22-cf896646d1a5")) {                    Plotly.newPlot(                        "b6ee9ca4-5472-4e85-9b22-cf896646d1a5",                        [{"close":[0.9510539770126344,0.7768189907073975,0.8825070261955261,0.7778319716453552,0.6619250178337097,0.646651029586792,0.6908159852027893,0.6607279777526855,0.6810960173606873,0.6069689989089966,0.538811981678009,0.5876590013504028,0.6916009783744812,0.6274570226669312,0.6342419981956482,0.6433290243148804,0.6355059742927551,0.5723720192909241,0.6612930297851562,0.7458400130271912,0.6910449862480164,0.7287939786911011,0.7158759832382202,0.6795349717140198,0.6
# ...

# %%
sol_recent = sol[sol['Date'] > '2021-12-30']

fig = go.Figure(data=[go.Candlestick(x=sol_recent['Date'],
                open=sol_recent['Open'],
                high=sol_recent['High'],
                low=sol_recent['Low'],
                close=sol_recent['Close'])])
fig.add_layout_image(
    dict(
        source="https://pbs.twimg.com/profile_images/1472933274209107976/6u-LQfjG_400x400.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
fig.update_layout(
    title='Solana Price In 2022',
    yaxis_title='Solana Price',
)
fig.show()
# Out:
# <div>                            <div id="80ffa0e9-50d3-41b4-978c-5f4f26591a83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80ffa0e9-50d3-41b4-978c-5f4f26591a83")) {                    Plotly.newPlot(                        "80ffa0e9-50d3-41b4-978c-5f4f26591a83",                        [{"close":[170.299072265625,178.5179443359375,176.38284301757812,170.29774475097656,167.93890380859375,155.0997314453125,150.4313507080078,136.40281677246094,142.51345825195312,140.83900451660156,135.95494079589844,140.18385314941406,151.70310974121094,146.01004028320312,146.15902709960938,147.80117797851562,147.8565216064453,139.92601013183594,141.58718872070312,135.79238891601562,127.20528411865234,111.96605682373048,94.1783676147461,99.5782241821289,91.65016174
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=sol['Date'],
                open=sol['Open'],
                high=sol['High'],
                low=sol['Low'],
                close=sol['Close'])])

fig.add_trace(go.Scatter(x=['2021-04-25','2022-06-20'], y=[78,78], mode='lines', name='trend line', line=dict(color='yellow')))
fig.add_trace(go.Scatter(x=['2021-04-25','2022-06-20'], y=[58,58], mode='lines', name='trend line', line=dict(color='blue')))
fig.add_trace(go.Scatter(x=['2021-02-13','2022-06-19'], y=[22,22], mode='lines', name='trend line', line=dict(color='purple')))
fig.add_layout_image(
    dict(
        source="https://pbs.twimg.com/profile_images/1472933274209107976/6u-LQfjG_400x400.jpg",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
fig.update_layout(
    title='Solana Important Support Levels',
    yaxis_title='Solana Price',
    xaxis_rangeslider_visible=False,
    annotations=[dict(
        x='2022-04-20', y=0.07, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Important Support Levels')]
)
# Out:
# <div>                            <div id="b9c83098-d220-430d-9998-69d0f5855e8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9c83098-d220-430d-9998-69d0f5855e8f")) {                    Plotly.newPlot(                        "b9c83098-d220-430d-9998-69d0f5855e8f",                        [{"close":[0.9510539770126344,0.7768189907073975,0.8825070261955261,0.7778319716453552,0.6619250178337097,0.646651029586792,0.6908159852027893,0.6607279777526855,0.6810960173606873,0.6069689989089966,0.538811981678009,0.5876590013504028,0.6916009783744812,0.6274570226669312,0.6342419981956482,0.6433290243148804,0.6355059742927551,0.5723720192909241,0.6612930297851562,0.7458400130271912,0.6910449862480164,0.7287939786911011,0.7158759832382202,0.6795349717140198,0.6
# ...

# %% [markdown]
# <div style = 'position: relative; text-align: center; color: white;'>
#   <img src="https://png.pngtree.com/thumb_back/fh260/background/20190421/pngtree-blockchain-technology-background-image_107831.jpg" style="width:100%;border-radius: 25px;">
#   <div style = 'position: absolute; top: 50%; left: 50%;transform: translate(-50%, -50%);font-size: 25px;font-weight: bold;'>
# BNB Technical Analysis</div>
# </div>

# %% [markdown]
# <img src= "https://techmoran.com/wp-content/uploads/2021/01/binance.jpg" alt ="BNB" >

# %% [markdown]
# # BNB

# %%
fig = go.Figure()

fig.add_trace(
    go.Scatter(x=list(bnb.Date), y=list(bnb.High)))

# Set title
fig.update_layout(
    title_text="BNB Time series with range slider and selectors"
)
fig.add_layout_image(
    dict(
        source="https://cdn.pixabay.com/photo/2021/04/30/16/47/bnb-6219388_640.png",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()
# Out:
# <div>                            <div id="2ba13bfe-38d6-4a54-95a2-2480ac30bcf8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ba13bfe-38d6-4a54-95a2-2480ac30bcf8")) {                    Plotly.newPlot(                        "2ba13bfe-38d6-4a54-95a2-2480ac30bcf8",                        [{"x":["2017-11-09T00:00:00","2017-11-10T00:00:00","2017-11-11T00:00:00","2017-11-12T00:00:00","2017-11-13T00:00:00","2017-11-14T00:00:00","2017-11-15T00:00:00","2017-11-16T00:00:00","2017-11-17T00:00:00","2017-11-18T00:00:00","2017-11-19T00:00:00","2017-11-20T00:00:00","2017-11-21T00:00:00","2017-11-22T00:00:00","2017-11-23T00:00:00","2017-11-24T00:00:00","2017-11-25T00:00:00","2017-11-26T00:00:00","2017-11-27T00:00:00","2017-11-28T00:00:00","2017-11-29T00:00:00"
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=bnb['Date'],
                open=bnb['Open'],
                high=bnb['High'],
                low=bnb['Low'],
                close=bnb['Close'])])

fig.add_layout_image(
    dict(
        source="https://cdn.pixabay.com/photo/2021/04/30/16/47/bnb-6219388_640.png",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)

fig.update_layout(
    title='BNB Price Over Time',
    yaxis_title='BNB Price',
    shapes = [dict(
        x0='2021-11-10', x1='2022-07-20', y0=0, y1=1, xref='x', yref='paper',
        line_width=2)],
    annotations=[dict(
        x='2022-06-01', y=0.05, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Bear Market Begins')]
)

fig.show()
# Out:
# <div>                            <div id="ebf98f7f-1519-425f-b6ed-a3d6d23e26c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebf98f7f-1519-425f-b6ed-a3d6d23e26c5")) {                    Plotly.newPlot(                        "ebf98f7f-1519-425f-b6ed-a3d6d23e26c5",                        [{"close":[1.99077,1.79684,1.67047,1.51969,1.68662,1.59258,1.53045,1.57792,1.51036,1.67433,1.61377,1.62445,1.57406,1.61175,1.5487,1.71771,1.87387,1.85313,1.94298,1.91711,1.75153,1.99697,2.07023,2.08416,2.22725,2.49168,2.5953,2.58769,2.77995,2.83067,2.61043,2.48337,2.70665,2.68475,2.7781,3.15874,3.99615,4.66465,5.75672,5.61585,5.79233,5.17621,5.18001,4.33615,4.83926,5.28568,6.56001,9.02942,10.107,9.32141,8.8076,7.84101,8.63558,8.41461,8.83777,9.53588,9.21399,14.917
# ...

# %%
bnb_recent = bnb[bnb['Date'] > '2021-12-30']

fig = go.Figure(data=[go.Candlestick(x=bnb_recent['Date'],
                open=bnb_recent['Open'],
                high=bnb_recent['High'],
                low=bnb_recent['Low'],
                close=bnb_recent['Close'])])
fig.add_layout_image(
    dict(
        source="https://cdn.pixabay.com/photo/2021/04/30/16/47/bnb-6219388_640.png",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
fig.update_layout(
    title='BNB Price In 2022',
    yaxis_title='BNB Price',
)
fig.show()
# Out:
# <div>                            <div id="2e2efa33-3509-4848-9552-0629f875fc21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e2efa33-3509-4848-9552-0629f875fc21")) {                    Plotly.newPlot(                        "2e2efa33-3509-4848-9552-0629f875fc21",                        [{"close":[511.708313,527.352722,531.396667,512.135986,507.506104,475.056946,473.275604,447.788483,430.246155,438.80307,424.933777,463.518311,487.007416,475.029114,489.867432,494.988068,498.427917,475.709869,472.005066,462.822083,440.005432,383.073914,358.096161,383.93396,371.368958,384.619354,375.755463,390.088287,386.084381,389.132782,377.612915,375.277313,385.463806,367.47168,370.877747,399.029602,414.200012,419.545563,433.229279,408.776764,422.465546,415.11923
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=bnb['Date'],
                open=bnb['Open'],
                high=bnb['High'],
                low=bnb['Low'],
                close=bnb['Close'])])

fig.add_trace(go.Scatter(x=['2021-04-25','2022-06-20'], y=[260,260], mode='lines', name='trend line', line=dict(color='black')))
fig.add_trace(go.Scatter(x=['2021-03-25','2022-06-20'], y=[230,230], mode='lines', name='trend line', line=dict(color='blue')))
fig.add_trace(go.Scatter(x=['2021-02-16','2022-06-19'], y=[190,190], mode='lines', name='trend line', line=dict(color='purple')))
fig.add_layout_image(
    dict(
        source="https://cdn.pixabay.com/photo/2021/04/30/16/47/bnb-6219388_640.png",
        xref="paper", yref="paper",
        x=1, y=1.05,
        sizex=0.2, sizey=0.2,
        xanchor="right", yanchor="bottom"
    )
)
fig.update_layout(
    title='BNB Important Support Levels',
    yaxis_title='BNB Price',
    xaxis_rangeslider_visible=False,
    annotations=[dict(
        x='2022-04-20', y=0.07, xref='x', yref='paper',
        showarrow=False, xanchor='right', text='Important Support Levels')]
)
# Out:
# <div>                            <div id="3613b2f5-8f3c-447e-8c41-93b0b72a6f87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3613b2f5-8f3c-447e-8c41-93b0b72a6f87")) {                    Plotly.newPlot(                        "3613b2f5-8f3c-447e-8c41-93b0b72a6f87",                        [{"close":[1.99077,1.79684,1.67047,1.51969,1.68662,1.59258,1.53045,1.57792,1.51036,1.67433,1.61377,1.62445,1.57406,1.61175,1.5487,1.71771,1.87387,1.85313,1.94298,1.91711,1.75153,1.99697,2.07023,2.08416,2.22725,2.49168,2.5953,2.58769,2.77995,2.83067,2.61043,2.48337,2.70665,2.68475,2.7781,3.15874,3.99615,4.66465,5.75672,5.61585,5.79233,5.17621,5.18001,4.33615,4.83926,5.28568,6.56001,9.02942,10.107,9.32141,8.8076,7.84101,8.63558,8.41461,8.83777,9.53588,9.21399,14.917
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning" style = 'font-size:16px;'> 📌 Please note that I am still working on this kernel and I am not a trader. This is just an educational notebook! </br>
#     For my support please upvote this kernel.</div>
